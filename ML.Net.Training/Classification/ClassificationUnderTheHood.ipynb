// %% [markdown]
// 1. Logistic Regression
//
// Similar to linear regression, this model is often used for classification and predictive analytics. In this model, we are mainly estimating the probability of an event happening. For the sake of simplicity, we will apply this to binary classification(only two classes). The basis of this algorithm is to find a linear boundry between the two classes. One class will be labeled 1(positive) and the other 0(negative), hence binary classification. When we do this, we can then create a continuous function whose codomain is (0,1). This continuous function is what provides the boundary of classification so that we can estimate/predict which class the given value falls under.
//
// ![logisticRegression](attachment:image.png)
//
// For this purpose we can use a sigmoid or standard logistic function -
//
// ![image.png](attachment:image-2.png)
//
// So we can calculate wX + b, or put it all into a matrix θX, and put the result in the sigmoid function. If the result is greater than 0.5, than we can mark that value as a positive class(1). If it falls lower than 0.5, we can mark it as a negative class(0). To visualize this process, you can use this formula -
//
// ![image.png](attachment:image-3.png)
//
// We still need to to modify the loss function in order to work on our data. However, we can't use the same formula as linear regression since forumla does have its closed form. In order to optimize it, we need to apply the gradient descent. To do that, we calculate partial derivatives of the cost function with regards to the j-th model parameter θj
//
// ![image.png](attachment:image-4.png)

// %% [markdown]
// 2. K-Nearest Neighbors (KNN)
//
// Unlike logistic regression, which we are calculating probabilities and estimates, KNN is based on local distances between data points. This mean that our models are not parameterized. There is no need as we just looking at what data is the closed point. This does however mean that we keep all of our training data in memory. Even after training is done. As you can deduce, storing the data is actually the training process. Once we pass a new, unseen sample to the algorithm, it calculates k number of examples that are closes to this new sample. It applies majority rules, ie we look at 5 samples, 3 are red and 2 are blue so we return that the new sample is red. We can calculate the distance in a number of different ways. However, the most common one used in practice is the Euclidean distance or Cosine similarity. The Euclidean distance is as follows -
//
// ![image.png](attachment:image.png)

// %% [markdown]
// 3. Naive Bayes
//
// Returning to a classification algorithm that calculates probability, in this algorithm we are trying to create a predictive model to estimate a conditional probability of a class label given its observation. This means that we calculate the probability for each class label and then simply pick the one with the highest probability. Bayes Theorem is as follows-
//
// ![image.png](attachment:image.png)
//
// There are flaws with this forumla as face value however. This formula assumes that each input variable is dependant on all the other variables. Meaning that we will need a very large dataset to calculate this probability. What if you have many input variables? This creates an even larger set which in turn creates an even bigger problem. To resolve this, we assume that the variables are actually independant of each other. In reality, they actually are dependant, but this approach of assuming independance actually proved correct. So we can rewrite this forumla-
//
// ![image.png](attachment:image-2.png)
//
// To get P(yi), we just have to divide the frequence of class yi in the training dataset and divide it with the total number of samples in the training set. (P(yi) = # of samples with yi/total # of examples).
